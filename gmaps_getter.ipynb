# %%
import requests
from PIL import Image
from io import BytesIO

# %%
address = '24 Bromley Street, Kangaroo Point, QLD 4169, Australia'
zoom = 19
maptype = 'satellite'
size = '500x500'
API_KEY = 'AIzaSyAYt1T9pSUAZ94dT7tqNseSPsRTfyZGblA'


url = "https://maps.googleapis.com/maps/api/staticmap?center={center}&zoom={zoom}&size={size}&maptype={maptype}&key={key}"


resp = requests.get(url.format(center=address, zoom=zoom, size=size, maptype=maptype, key=API_KEY))

# %%
im = Image.open(BytesIO(resp.content))
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x500 at 0x7F04781B9208>

# %%
gm.place('McDonnalds, Brisbane')
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-6-6f1e1afeaea1> in <module>
# ----> 1 gm.place('McDonnalds, Brisbane')
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     416     def wrapper(*args, **kwargs):
#     417         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 418         result = func(*args, **kwargs)
#     419         try:
#     420             del args[0]._extra_params
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/googlemaps/places.py in place(client, place_id, session_token, fields, language)
#     446         params["sessiontoken"] = session_token
#     447
# --> 448     return client._request("/maps/api/place/details/json", params)
#     449
#     450
#
# ...
